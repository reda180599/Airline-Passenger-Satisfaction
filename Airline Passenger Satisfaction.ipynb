# %% [markdown]
# ## Airline Passenger Satisfaction

# %% [markdown]
# Field          Description
#
# 1- ID =======> Unique passenger identifier
#
# 2- Gender =====> Gender of the passenger (Female/Male)
#
# 3- Age =====> Age of the passenger
#
# 4- Customer Type =====> Type of airline customer (First-time/Returning)
#
# 5- Type of Travel ======> Purpose of the flight (Business/Personal)
#
# 6- Class ======> Travel class in the airplane for the passenger seat
#
# 7- Flight Distance ======> Flight distance in miles
#
# 8- Departure Delay ========> Flight departure delay in minutes
#
# 9- Arrival Delay =======> Flight arrival delay in minutes
#
# 10- Departure and Arrival Time Convenience =======> "Satisfaction level with the convenience of the flight departure and arrival times from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 11- Ease of Online Booking =======> "Satisfaction level with the online booking experience from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 12- Check-in Service =======> "Satisfaction level with the check-in service from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 13- Online Boarding =============> "Satisfaction level with the online boarding experience from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 14- Gate Location =======> "Satisfaction level with the gate location in the airport from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 15- On-board Service ==========> "Satisfaction level with the on-boarding service in the airport from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 16- Seat Comfort =============> "Satisfaction level with the comfort of the airplane seat from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 17- Leg Room Service =============> "Satisfaction level with the leg room of the airplane seat from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 18- Cleanliness ============> "Satisfaction level with the cleanliness of the airplane from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 19- Food and Drink ===========> "Satisfaction level with the food and drinks on the airplane from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 20- In-flight Service =========> "Satisfaction level with the in-flight service from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 21- In-flight Wifi Service =========> "Satisfaction level with the in-flight Wifi service from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 22- In-flight Entertainment ===========> "Satisfaction level with the in-flight entertainment from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 23- Baggage Handling =========> "Satisfaction level with the baggage handling from the airline from 1 (lowest) to 5 (highest) - 0 means ""not applicable"""
#
# 24- Satisfaction ===========> Overall satisfaction level with the airline (Satisfied/Neutral or unsatisfied)

# %% [markdown]
# ## Toolbox

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Read Data

# %%
df = pd.read_csv('airline_passenger_satisfaction.csv', sep=',')

df.head()
# Out:
#    ID  Gender  Age Customer Type Type of Travel     Class  Flight Distance  \
# 0   1    Male   48    First-time       Business  Business              821
# 1   2  Female   35     Returning       Business  Business              821
# 2   3    Male   41     Returning       Business  Business              853
# 3   4    Male   50     Returning       Business  Business             1905
# 4   5  Female   49     Returning       Business  Business             3470
#
#    Departure Delay  Arrival Delay  Departure and Arrival Time Convenience  \
# 0                2            5.0                                       3
# 1               26           39.0                                       2
# 2                0            0.0                                       4
# 3                0            0.0                                       2
# 4                0            1.0                                       3
#
# ...

# %% [markdown]
# ##  Data Exploration

# %%
df.shape                # number of columns and number of rows
# Out:
# (129880, 24)

# %%
df.dtypes               # types of data
# Out:
# ID                                          int64
# Gender                                     object
# Age                                         int64
# Customer Type                              object
# Type of Travel                             object
# Class                                      object
# Flight Distance                             int64
# Departure Delay                             int64
# Arrival Delay                             float64
# Departure and Arrival Time Convenience      int64
# Ease of Online Booking                      int64
# Check-in Service                            int64
# Online Boarding                             int64
# Gate Location                               int64
# On-board Service                            int64
# Seat Comfort                                int64
# Leg Room Service                            int64
# Cleanliness                                 int64
# Food and Drink                              int64
# ...

# %%
df.info()                # More info about the data - #null values #count #data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count   Dtype
# ---  ------                                  --------------   -----
#  0   ID                                      129880 non-null  int64
#  1   Gender                                  129880 non-null  object
#  2   Age                                     129880 non-null  int64
#  3   Customer Type                           129880 non-null  object
#  4   Type of Travel                          129880 non-null  object
#  5   Class                                   129880 non-null  object
#  6   Flight Distance                         129880 non-null  int64
#  7   Departure Delay                         129880 non-null  int64
#  8   Arrival Delay                           129487 non-null  float64
#  9   Departure and Arrival Time Convenience  129880 non-null  int64
# ...

# %%
df.describe()                  # The distribution of Data
# Out:
#                   ID            Age  Flight Distance  Departure Delay  \
# count  129487.000000  129487.000000     49453.000000    129487.000000
# mean    64958.335169      39.428761       348.491497        14.643385
# std     37489.781165      15.117597       142.741625        37.932867
# min         1.000000       7.000000        31.000000         0.000000
# 25%     32494.500000      27.000000       231.000000         0.000000
# 50%     64972.000000      40.000000       345.000000         0.000000
# 75%     97415.500000      51.000000       460.000000        12.000000
# max    129880.000000      85.000000       600.000000      1592.000000
#
#        Arrival Delay  Departure and Arrival Time Convenience  \
# count  129487.000000                           129487.000000
# mean       15.091129                                3.057349
# std        38.465650                                1.526787
# min         0.000000                                0.000000
# ...

# %% [markdown]
# ## Know More about The Data & Fields

# %%
oldPassenger = df['Age'].max()                # The oldest passenger and the smallest one
smallPassenger = df['Age'].min()

print('Small Passenger has ' , smallPassenger , 'The Oldest Passenger has ' , oldPassenger)
# Out:
# Small Passenger has  7 The Oldest Passenger has  85

# %%
df['Arrival Delay'].mean()                   # The mean of Arrival Delay in minutes
# Out:
# 15.09112883918849

# %%
df['Type of Travel'].value_counts()          # Type of Travel business or personal
# Out:
# Business    89693
# Personal    40187
# Name: Type of Travel, dtype: int64

# %%
df['Class'].value_counts()                 # Type of Class Business, Economy or Economy Plus
# Out:
# Business        62160
# Economy         58309
# Economy Plus     9411
# Name: Class, dtype: int64

# %%
df['Customer Type'].value_counts()         # type of the passenger First Time or Returning
# Out:
# Returning     106100
# First-time     23780
# Name: Customer Type, dtype: int64

# %%
df['Baggage Handling'].value_counts()       # Satification Level of Baggage Handling
# Out:
# 4    46761
# 5    33878
# 3    25851
# 2    14362
# 1     9028
# Name: Baggage Handling, dtype: int64

# %%
df['Cleanliness'].value_counts()            # Satification Level of Cleanliness
# Out:
# 4    33969
# 3    30639
# 5    28416
# 2    20113
# 1    16729
# 0       14
# Name: Cleanliness, dtype: int64

# %%
df['Ease of Online Booking'].value_counts()  # Satification Level of Ease of Online Booking
# Out:
# 3    30393
# 2    30051
# 4    24444
# 1    21886
# 5    17424
# 0     5682
# Name: Ease of Online Booking, dtype: int64

# %%
df['Check-in Service'].value_counts()      # Satification Level of Check-in Service
# Out:
# 4    36333
# 3    35453
# 5    25883
# 1    16108
# 2    16102
# 0        1
# Name: Check-in Service, dtype: int64

# %%
df['Flight Distance'].mean()               # The average of Distance for all Flights
# Out:
# 1190.3163920542038

# %%
df['Food and Drink'].value_counts()        # Satification Level of Food and Drink
# Out:
# 4    30563
# 5    27957
# 3    27794
# 2    27383
# 1    16051
# 0      132
# Name: Food and Drink, dtype: int64

# %%
df['In-flight Wifi Service'].value_counts()  # Satification Level of In-flight Wifi Service
# Out:
# 2    32320
# 3    32185
# 4    24775
# 1    22328
# 5    14356
# 0     3916
# Name: In-flight Wifi Service, dtype: int64

# %%
df['In-flight Service'].value_counts()  # Satification Level of In-flight Service
# Out:
# 4    47323
# 5    34066
# 3    25316
# 2    14308
# 1     8862
# 0        5
# Name: In-flight Service, dtype: int64

# %%
df['Leg Room Service'].value_counts()  # Satification Level of Leg Room Service
# Out:
# 4    35886
# 5    30905
# 3    25056
# 2    24540
# 1    12895
# 0      598
# Name: Leg Room Service, dtype: int64

# %%
df['On-board Service'].value_counts()  # Satification Level of On-board Service
# Out:
# 4    38703
# 5    29492
# 3    28542
# 2    18351
# 1    14787
# 0        5
# Name: On-board Service, dtype: int64

# %%
df['Gender'].value_counts()            # Gender  ==>   #Male  #Female
# Out:
# Female    65899
# Male      63981
# Name: Gender, dtype: int64

# %%
df['Gate Location'].value_counts()       # Satification Level of Gate Location
# Out:
# 3    35717
# 4    30466
# 2    24296
# 1    21991
# 5    17409
# 0        1
# Name: Gate Location, dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### 1- Handle Missing / Null Values

# %%
df.isnull().sum()
# Out:
# ID                                          0
# Gender                                      0
# Age                                         0
# Customer Type                               0
# Type of Travel                              0
# Class                                       0
# Flight Distance                             0
# Departure Delay                             0
# Arrival Delay                             393
# Departure and Arrival Time Convenience      0
# Ease of Online Booking                      0
# Check-in Service                            0
# Online Boarding                             0
# Gate Location                               0
# On-board Service                            0
# Seat Comfort                                0
# Leg Room Service                            0
# Cleanliness                                 0
# Food and Drink                              0
# In-flight Service                           0
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
round((df.isnull().sum() / df['ID'].count()) * 100, 2)   # Percentage of null values compared with the dataset
# Out:
# ID                                        0.0
# Gender                                    0.0
# Age                                       0.0
# Customer Type                             0.0
# Type of Travel                            0.0
# Class                                     0.0
# Flight Distance                           0.0
# Departure Delay                           0.0
# Arrival Delay                             0.3
# Departure and Arrival Time Convenience    0.0
# Ease of Online Booking                    0.0
# Check-in Service                          0.0
# Online Boarding                           0.0
# Gate Location                             0.0
# On-board Service                          0.0
# Seat Comfort                              0.0
# Leg Room Service                          0.0
# Cleanliness                               0.0
# Food and Drink                            0.0
# In-flight Service                         0.0
# ...

# %%
df.dropna(inplace=True)         # Axis by default = 0 , and inplace to deal with the original dataset

# %%
sns.heatmap(df.isnull())        # Now it's free from null/ Missing values
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 2- Handle Duplicated Values

# %%
df.duplicated().sum()            # No duplicates Values
# Out:
# 0

# %% [markdown]
# ### 3- Handle Outliers

# %%
sns.boxplot(data=df['Age'])
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(data=df['Flight Distance'])
# Out:
# <AxesSubplot:>

# %%
def handel_outlier_weight(x):
    if x >600:
        return np.nan
    else:
        return x

# %%
df['Flight Distance'] = df['Flight Distance'].apply(handel_outlier_weight)

# %%
df['Flight Distance'] = df['Flight Distance'].fillna(df['Flight Distance'].mode())

# %%
sns.boxplot(data=df['Flight Distance'])
# Out:
# <AxesSubplot:>

# %%
from datasist.structdata import detect_outliers # Another way to detct and handle outliers

# %%
outliers = detect_outliers(df, 0, ['Arrival Delay']) # 0 means get all the outliers

len(outliers)
# Out:
# 17492

# %%
df['Arrival Delay'].sort_values(ascending=False).head(5)
# Out:
# 73470    1584.0
# 69660    1280.0
# 73481    1115.0
# 4902     1011.0
# 78299     970.0
# Name: Arrival Delay, dtype: float64

# %% [markdown]
# ## Data Visualizatio - EDA /  Exploratory Data Analysis

# %% [markdown]
# ### Data Correlation

# %%
plt.figure(figsize=[14, 8])
sns.heatmap(df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 1- Univariante Analysis

# %% [markdown]
# ### How many Flights that There is no Arival Delay and What is it's Percentage

# %%
(sum(df['Arrival Delay'] == 0)/ df['Arrival Delay'].count())*100
# Out:
# 56.18556302949331

# %%
plt.figure(figsize=[7, 7])

colors=sns.color_palette('pastel')[0:5]
(df['Arrival Delay'] == 0).value_counts().plot.pie( colors = colors, autopct='%0.2f%%')

plt.title(label='How many Flights that There is no Arival Delay? and What is its Percentage?',loc='center')
plt.show()

# %% [markdown]
# ### Overall Satisfaction Level

# %%
plt.figure(figsize=[7, 7])

colors=sns.color_palette('pastel')[0:5]
df['Satisfaction'].value_counts().plot.pie( colors = colors, autopct='%0.2f%%')

plt.title(label='Overall Satisfaction',loc='center')
plt.show()

# %% [markdown]
# ### The percentage of Gender

# %%
plt.figure(figsize=[7, 7])
plt.title(label='Gender Male or Female',loc='center')
df['Gender'].value_counts().plot.pie(autopct='%0.2f%%')
# Out:
# <AxesSubplot:title={'center':'Gender Male or Female'}, ylabel='Gender'>

# %% [markdown]
# ### Class Type

# %%
plt.figure(figsize=[7, 7])
plt.title(label='Class Type Business / Economy / Economy Pluse',loc='center')
df['Class'].value_counts().plot.pie(autopct='%0.2f%%')
# Out:
# <AxesSubplot:title={'center':'Class Type Business / Economy / Economy Pluse'}, ylabel='Class'>

# %% [markdown]
# ### Customer Type

# %%
plt.figure(figsize=[7, 7])
plt.title(label='Customer Type First Time / Returning',loc='center')
df['Customer Type'].value_counts().plot.pie(autopct='%0.2f%%')
# Out:
# <AxesSubplot:title={'center':'Customer Type First Time / Returning'}, ylabel='Customer Type'>

# %% [markdown]
# ### Baggage Handling Satisfication Level

# %%
sns.histplot(data=df, x='Baggage Handling', bins=10)
# Out:
# <AxesSubplot:xlabel='Baggage Handling', ylabel='Count'>

# %% [markdown]
# ### Type of Travel

# %%
plt.figure(figsize=[7, 7])

plt.title(label='Type of The travel Personal or Business',loc='center')
df['Type of Travel'].value_counts().plot.pie(autopct='%0.2f%%')
# Out:
# <AxesSubplot:title={'center':'Type of The travel Personal or Business'}, ylabel='Type of Travel'>

# %% [markdown]
# ## Bivariante Analysis & MultiVariante Analysis

# %% [markdown]
# ### What is the demographic profile of the passengers who are most satisfied with the airline services?

# %%
df[df['Satisfaction'] == 'Satisfied']
# Out:
#             ID  Gender  Age Customer Type Type of Travel         Class  \
# 1            2  Female   35     Returning       Business      Business
# 2            3    Male   41     Returning       Business      Business
# 3            4    Male   50     Returning       Business      Business
# 4            5  Female   49     Returning       Business      Business
# 5            6    Male   43     Returning       Business      Business
# ...        ...     ...  ...           ...            ...           ...
# 129863  129864  Female   39     Returning       Business      Business
# 129864  129865    Male   38     Returning       Business      Business
# 129866  129867  Female   20    First-time       Business       Economy
# 129871  129872  Female   32     Returning       Business  Economy Plus
# 129878  129879    Male   50     Returning       Personal  Economy Plus
#
#         Flight Distance  Departure Delay  Arrival Delay  \
# 1                   NaN               26           39.0
# ...

# %% [markdown]
# ### How does the satisfaction level vary based on the type of customer (first-time or returning)?

# %%
plt.figure(figsize=[10, 6])

plt.title(label='Satisfication level based on the type of The travel Personal or Business',loc='center')
sns.countplot(data=df, x= 'Satisfaction', hue='Customer Type')
# Out:
# <AxesSubplot:title={'center':'Satisfication level based on the type of The travel Personal or Business'}, xlabel='Satisfaction', ylabel='count'>

# %% [markdown]
# ### Is there a significant difference in satisfaction levels between business and personal travelers?

# %%
plt.figure(figsize=[10, 6])

plt.title(label='Satisfication Level basedon Traverlers Personal or business',loc='center')
sns.countplot(data=df, x= 'Satisfaction', hue='Type of Travel')
# Out:
# <AxesSubplot:title={'center':'Satisfication Level basedon Traverlers Personal or business'}, xlabel='Satisfaction', ylabel='count'>

# %% [markdown]
# ### How do the different classes of travel (economy, business, first) impact the overall satisfaction of passengers?

# %%
plt.figure(figsize=[10, 6])

plt.title(label='Satisfication Level based on classes of travel (economy, business, first) ',loc='center')
sns.countplot(data=df, x= 'Satisfaction', hue='Class')
# Out:
# <AxesSubplot:title={'center':'Satisfication Level based on classes of travel (economy, business, first) '}, xlabel='Satisfaction', ylabel='count'>

# %% [markdown]
# ### Are there any specific services that are consistently rated higher or lower by passengers?

# %%
def services(x):
    
    cleanliness = sum(df['Cleanliness'] == x)
    check_in_Service = sum(df['Check-in Service'] == x)
    Baggage = sum(df['Baggage Handling'] == x)
    Online_Booking = sum(df['Ease of Online Booking'] == x)
    Food_Drink = sum(df['Food and Drink'] == x)
    Entertainment = sum(df['In-flight Entertainment'] == x)
    flight_Service = sum(df['In-flight Service'] == x)
    Wifi = sum(df['In-flight Wifi Service'] == x)
    Room = sum(df['Leg Room Service'] == x)
    Seat = sum(df['Seat Comfort'] == x)
    
    
    list = [Seat, Room, Wifi, flight_Service, Food_Drink, Online_Booking, Baggage, check_in_Service, cleanliness,Entertainment]
    
    plt.figure(figsize=[12, 6])
    plt.title('Seat,  Room,  Wifi,  flight_Service,  Food_Drink,  Online_Booking,  Baggage,  check_in_Service,  cleanliness, Entertainment')
    sns.histplot(data=list, bins = 10, kde=True, alpha=0.5, color='g')
    
    for p in plt.gca().patches:
        plt.gca().annotate(f"{p.get_height()}", (p.get_x() + p.get_width() / 2., p.get_height()), 
                       ha='center', va='center',xytext=(0, 10), textcoords='offset points')
        sns.set_style("whitegrid")
        sns.despine()  # remove the top and right spines



    # show the plot
    plt.show()

# %%
services(5)             #  services that are consistently rated higher

# %%
services(4)                  # services that are consistently rated higher

# %%
services(3)                       #services that are consistently rated = 3

# %%
services(2)                  # services that are consistently rated low

# %%
services(1)                     #services that are consistently rated low

# %%
services(0)             #services that are consistently rated = 0

# %% [markdown]
# ### Is there a correlation between flight distance and overall satisfaction level?

# %%
sns.scatterplot(data=df, x="Flight Distance", y = 'In-flight Entertainment', hue="Satisfaction")

# customize the plot
plt.title("Flight Distance vs In-flight Entertainment Satisfaction")
plt.xlabel("Distance (miles)")
plt.ylabel("In-flight Entertainment")

sns.set_style("whitegrid")
plt.figure(figsize=[12, 6])
# show the plot
plt.show()

# %% [markdown]
# ### How do flight delays impact passenger satisfaction?

# %%
sns.scatterplot(data=df, x="Departure and Arrival Time Convenience", y="Satisfaction")

# customize the plot
plt.title("Departure and Arrival Time Convenience vs Overall Satisfaction")
plt.xlabel("Departure and Arrival Time Conveniencee (minutes)")
plt.ylabel("Overall Satisfaction")
plt.figure(figsize=[12, 6])
# show the plot
plt.show()

# %%
sns.scatterplot(data=df, x="Departure Delay", y="Satisfaction")

# customize the plot
plt.title("Departure and Arrival Time Convenience vs Overall Satisfaction")
plt.xlabel("Departure and Arrival Time Conveniencee (minutes)")
plt.ylabel("Overall Satisfaction")
plt.figure(figsize=[12, 6])
# show the plot
plt.show()

# %% [markdown]
# ### Is there a correlation between the satisfaction level and the Gender or cleanliness of the airplane?

# %%
sns.set_style("whitegrid")
plt.figure(figsize=[12, 6])
sns.countplot(data=df, x="Gender", hue="Satisfaction")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
sns.set_style("whitegrid")
plt.figure(figsize=[12, 6])
sns.countplot(data=df, x="Cleanliness", hue="Satisfaction")
# Out:
# <AxesSubplot:xlabel='Cleanliness', ylabel='count'>

# %%
sns.set_style("whitegrid")
plt.figure(figsize=[12, 6])
sns.countplot(data=df, x="Ease of Online Booking", hue="Satisfaction")
# Out:
# <AxesSubplot:xlabel='Ease of Online Booking', ylabel='count'>

# %% [markdown]
# ### overall satisfaction levels by flight class

# %%
plt.figure(figsize=[12, 6])
sns.countplot(data=df, x="Class", hue="Satisfaction", palette="Set2", saturation=0.8)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
plt.figure(figsize=[12, 6])
sns.countplot(data=df, x="Class", hue="Customer Type", palette="Set2", saturation=0.8)
# Out:
# <AxesSubplot:xlabel='Class', ylabel='count'>

# %%
plt.figure(figsize=[12, 6])
sns.countplot(data=df, x="Satisfaction", hue="Customer Type", palette="Set2", saturation=0.8)
# Out:
# <AxesSubplot:xlabel='Satisfaction', ylabel='count'>
